# %%
import random

import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.models import Model

RANDOM_SEED = 2_055
IMG_SIZE = (8, 8, 1)

# %%
def create_model():
    input_layer = layers.Input(shape=IMG_SIZE)
    layer_conv1_1 = layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        input_layer)
    layer_conv1_2 = layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        layer_conv1_1)
    layer_pool1 = layers.MaxPool2D(pool_size=(2, 2))(layer_conv1_2)

    layer_conv2_1 = layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        layer_pool1)
    layer_conv2_2 = layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        layer_conv2_1)
    layer_pool2 = layers.MaxPool2D(pool_size=(2, 2))(layer_conv2_2)

    layer_conv3_1 = layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        layer_pool2)
    layer_conv3_2 = layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        layer_conv3_1)
    layer_flatten = layers.Flatten()(layer_conv3_2)

    dense_hidden1 = layers.Dense(32, activation='relu')(layer_flatten)
    dense_hidden2 = layers.Dense(64, activation='relu')(dense_hidden1)
    dense_hidden3 = layers.Dense(128, activation='relu')(dense_hidden2)

    dense_output = layers.Dense(10, activation='softmax')(dense_hidden3)

    model = Model(inputs=[input_layer], outputs=[dense_output])

    return model

# %%
def get_data():
    digit_dataset = load_digits()

    digit_data = digit_dataset.images
    digit_data = np.divide(digit_data, 255)  # Transform 0-255 to 0-1
    digit_data = np.expand_dims(digit_data, axis=-1)  # Add extra dimension to 2D image to make it 3D

    return digit_data, digit_dataset.target

# %%
X, y = get_data()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=RANDOM_SEED)

# %%
# Check data has been loaded property
plt.figure(figsize=(10, 10))
plt.title("Random train sample", pad=30)
plt.axis("off")

for i in range(9):
    random_num = random.randint(0, X_train.shape[0])
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(X_train[random_num], cmap='gray')
    plt.title(y_train[random_num])
    plt.axis("off")

# %%
model_base = create_model()
model_base.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='digit_model.keras',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=True)

history_model_base = model_base.fit(x=X_train,
                                    y=y_train,
                                    epochs=40,
                                    validation_data=(X_test, y_test),
                                    callbacks=[model_checkpoint_callback],
                                    verbose=True)
# Out:
# Epoch 1/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.0956 - loss: 2.3033
# Epoch 1: val_accuracy improved from -inf to 0.09074, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.0955 - loss: 2.3033 - val_accuracy: 0.0907 - val_loss: 2.3034
# Epoch 2/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.1010 - loss: 2.3025
# Epoch 2: val_accuracy improved from 0.09074 to 0.09630, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 188ms/step - accuracy: 0.1010 - loss: 2.3025 - val_accuracy: 0.0963 - val_loss: 2.3037
# Epoch 3/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.0742 - loss: 2.3016
# Epoch 3: val_accuracy did not improve from 0.09630
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 204ms/step - accuracy: 0.0743 - loss: 2.3016 - val_accuracy: 0.0907 - val_loss: 2.3045
# Epoch 4/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.1165 - loss: 2.3012
# Epoch 4: val_accuracy did not improve from 0.09630
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 177ms/step - accuracy: 0.1162 - loss: 2.3012 - val_accuracy: 0.0907 - val_loss: 2.3050
# Epoch 5/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.1013 - loss: 2.3023
# Epoch 5: val_accuracy did not improve from 0.09630
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 0.1014 - loss: 2.3023 - val_accuracy: 0.0963 - val_loss: 2.3052
# Epoch 6/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.1089 - loss: 2.3020
# Epoch 6: val_accuracy did not improve from 0.09630
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - accuracy: 0.1088 - loss: 2.3020 - val_accuracy: 0.0907 - val_loss: 2.3059
# Epoch 7/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.1141 - loss: 2.3019
# Epoch 7: val_accuracy did not improve from 0.09630
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 0.1139 - loss: 2.3019 - val_accuracy: 0.0907 - val_loss: 2.3066
# Epoch 8/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.1103 - loss: 2.3015
# Epoch 8: val_accuracy did not improve from 0.09630
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - accuracy: 0.1102 - loss: 2.3015 - val_accuracy: 0.0907 - val_loss: 2.3069
# Epoch 9/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.1186 - loss: 2.2822
# Epoch 9: val_accuracy improved from 0.09630 to 0.17407, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 175ms/step - accuracy: 0.1190 - loss: 2.2809 - val_accuracy: 0.1741 - val_loss: 2.0623
# Epoch 10/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.2137 - loss: 1.9409
# Epoch 10: val_accuracy improved from 0.17407 to 0.39259, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 177ms/step - accuracy: 0.2152 - loss: 1.9370 - val_accuracy: 0.3926 - val_loss: 1.5521
# Epoch 11/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.3973 - loss: 1.4543
# Epoch 11: val_accuracy improved from 0.39259 to 0.50556, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - accuracy: 0.3979 - loss: 1.4520 - val_accuracy: 0.5056 - val_loss: 1.1379
# Epoch 12/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5406 - loss: 1.0879
# Epoch 12: val_accuracy improved from 0.50556 to 0.63704, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - accuracy: 0.5418 - loss: 1.0855 - val_accuracy: 0.6370 - val_loss: 0.8351
# Epoch 13/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.6970 - loss: 0.7674
# Epoch 13: val_accuracy improved from 0.63704 to 0.79074, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 172ms/step - accuracy: 0.6977 - loss: 0.7657 - val_accuracy: 0.7907 - val_loss: 0.6271
# Epoch 14/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8244 - loss: 0.5403
# Epoch 14: val_accuracy improved from 0.79074 to 0.82778, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 0.8250 - loss: 0.5382 - val_accuracy: 0.8278 - val_loss: 0.5632
# Epoch 15/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.8584 - loss: 0.4342
# Epoch 15: val_accuracy improved from 0.82778 to 0.92222, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 0.8588 - loss: 0.4330 - val_accuracy: 0.9222 - val_loss: 0.2373
# Epoch 16/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9129 - loss: 0.2667
# Epoch 16: val_accuracy improved from 0.92222 to 0.93889, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - accuracy: 0.9124 - loss: 0.2680 - val_accuracy: 0.9389 - val_loss: 0.2253
# Epoch 17/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9368 - loss: 0.2204
# Epoch 17: val_accuracy did not improve from 0.93889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9368 - loss: 0.2200 - val_accuracy: 0.9074 - val_loss: 0.2914
# Epoch 18/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9667 - loss: 0.1179
# Epoch 18: val_accuracy improved from 0.93889 to 0.95741, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 0.9665 - loss: 0.1184 - val_accuracy: 0.9574 - val_loss: 0.1524
# Epoch 19/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9501 - loss: 0.1279
# Epoch 19: val_accuracy improved from 0.95741 to 0.95926, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 166ms/step - accuracy: 0.9503 - loss: 0.1276 - val_accuracy: 0.9593 - val_loss: 0.1541
# Epoch 20/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9675 - loss: 0.0955
# Epoch 20: val_accuracy did not improve from 0.95926
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 161ms/step - accuracy: 0.9676 - loss: 0.0953 - val_accuracy: 0.9389 - val_loss: 0.2370
# Epoch 21/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9807 - loss: 0.0670
# Epoch 21: val_accuracy improved from 0.95926 to 0.97037, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - accuracy: 0.9806 - loss: 0.0671 - val_accuracy: 0.9704 - val_loss: 0.1165
# Epoch 22/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9889 - loss: 0.0410
# Epoch 22: val_accuracy did not improve from 0.97037
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.9888 - loss: 0.0413 - val_accuracy: 0.9537 - val_loss: 0.1823
# Epoch 23/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9721 - loss: 0.0696
# Epoch 23: val_accuracy did not improve from 0.97037
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - accuracy: 0.9721 - loss: 0.0699 - val_accuracy: 0.9167 - val_loss: 0.3185
# Epoch 24/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9396 - loss: 0.2248
# Epoch 24: val_accuracy did not improve from 0.97037
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 151ms/step - accuracy: 0.9400 - loss: 0.2235 - val_accuracy: 0.9685 - val_loss: 0.1586
# Epoch 25/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9890 - loss: 0.0534
# Epoch 25: val_accuracy improved from 0.97037 to 0.97222, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 168ms/step - accuracy: 0.9890 - loss: 0.0534 - val_accuracy: 0.9722 - val_loss: 0.1210
# Epoch 26/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9989 - loss: 0.0118
# Epoch 26: val_accuracy did not improve from 0.97222
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.9989 - loss: 0.0119 - val_accuracy: 0.9704 - val_loss: 0.1275
# Epoch 27/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9952 - loss: 0.0227
# Epoch 27: val_accuracy did not improve from 0.97222
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9952 - loss: 0.0226 - val_accuracy: 0.9611 - val_loss: 0.2101
# Epoch 28/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9926 - loss: 0.0208
# Epoch 28: val_accuracy improved from 0.97222 to 0.97407, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - accuracy: 0.9927 - loss: 0.0206 - val_accuracy: 0.9741 - val_loss: 0.1139
# Epoch 29/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9999 - loss: 0.0035
# Epoch 29: val_accuracy improved from 0.97407 to 0.97593, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 173ms/step - accuracy: 0.9999 - loss: 0.0036 - val_accuracy: 0.9759 - val_loss: 0.1036
# Epoch 30/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9973 - loss: 0.0071
# Epoch 30: val_accuracy did not improve from 0.97593
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 158ms/step - accuracy: 0.9974 - loss: 0.0071 - val_accuracy: 0.9741 - val_loss: 0.1690
# Epoch 31/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9944 - loss: 0.0216
# Epoch 31: val_accuracy improved from 0.97593 to 0.97778, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 174ms/step - accuracy: 0.9944 - loss: 0.0215 - val_accuracy: 0.9778 - val_loss: 0.1001
# Epoch 32/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9682 - loss: 0.1082
# Epoch 32: val_accuracy did not improve from 0.97778
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9681 - loss: 0.1086 - val_accuracy: 0.9500 - val_loss: 0.1795
# Epoch 33/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9686 - loss: 0.0995
# Epoch 33: val_accuracy did not improve from 0.97778
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 0.9688 - loss: 0.0988 - val_accuracy: 0.9722 - val_loss: 0.0953
# Epoch 34/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9881 - loss: 0.0464
# Epoch 34: val_accuracy did not improve from 0.97778
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - accuracy: 0.9881 - loss: 0.0463 - val_accuracy: 0.9667 - val_loss: 0.1742
# Epoch 35/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9915 - loss: 0.0324
# Epoch 35: val_accuracy improved from 0.97778 to 0.98333, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 0.9915 - loss: 0.0322 - val_accuracy: 0.9833 - val_loss: 0.1051
# Epoch 36/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9995 - loss: 0.0060
# Epoch 36: val_accuracy improved from 0.98333 to 0.98519, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9995 - loss: 0.0060 - val_accuracy: 0.9852 - val_loss: 0.0766
# Epoch 37/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9959 - loss: 0.0092
# Epoch 37: val_accuracy improved from 0.98519 to 0.98704, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 174ms/step - accuracy: 0.9959 - loss: 0.0091 - val_accuracy: 0.9870 - val_loss: 0.0775
# Epoch 38/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9994 - loss: 0.0028
# Epoch 38: val_accuracy did not improve from 0.98704
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.9994 - loss: 0.0028 - val_accuracy: 0.9870 - val_loss: 0.0855
# Epoch 39/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9995 - loss: 0.0020
# Epoch 39: val_accuracy did not improve from 0.98704
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.9995 - loss: 0.0020 - val_accuracy: 0.9852 - val_loss: 0.0815
# Epoch 40/40
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9983 - loss: 0.0107
# Epoch 40: val_accuracy did not improve from 0.98704
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.9982 - loss: 0.0108 - val_accuracy: 0.9833 - val_loss: 0.0911

# %%
np.save('./history.npy', history_model_base.history)

# %%
# Método para la visualización de la exactitud obtenida durante el proceso de entrenamiento tanto en entrenamiento como en validación
def plot_losses(history):
    figure = plt.figure()
    axes = figure.add_subplot()
    axes.set_facecolor("#F0F7FF")
    axes.plot(history.history['loss'], label="Training", linestyle='dashed', color='#003B80')
    axes.plot(history.history['val_loss'], label="Validation", color='#003B80')
    axes.legend(loc="best")
    axes.set_ylabel('Loss')
    axes.set_xlabel('Epochs')
    axes.set_title('Loss during training')
    return figure


# Método para la visualización de la exactitud obtenida durante el proceso de entrenamiento tanto en entrenamiento como en validación
def plot_accuracy(history):
    figure = plt.figure()
    axes = figure.add_subplot()
    axes.set_facecolor("#F0F7FF")
    axes.plot(history.history['accuracy'], label="Training", linestyle='dashed', color='#003B80')
    axes.plot(history.history['val_accuracy'], label="Validation", color='#003B80')
    axes.legend(loc="best")
    axes.set_ylabel('Accuracy')
    axes.set_xlabel('Epochs')
    axes.set_title('Accuracy during training')
    return figure

# %%
_ = plot_losses(history_model_base)

# %%
_ = plot_accuracy(history_model_base)
