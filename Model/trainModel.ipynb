# %%
import random

import numpy as np
import tensorflow as tf
from keras import Model
from matplotlib import pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers

RANDOM_SEED = 2_055
IMG_SIZE = (8, 8, 1)

# %%
def create_model():
    input_layer = layers.Input(shape=IMG_SIZE)
    layer_conv1_1 = layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        input_layer)
    layer_conv1_2 = layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        layer_conv1_1)
    layer_pool1 = layers.MaxPool2D(pool_size=(2, 2))(layer_conv1_2)

    layer_conv2_1 = layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        layer_pool1)
    layer_conv2_2 = layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        layer_conv2_1)
    layer_pool2 = layers.MaxPool2D(pool_size=(2, 2))(layer_conv2_2)

    layer_conv3_1 = layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        layer_pool2)
    layer_conv3_2 = layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), padding="same", activation="relu")(
        layer_conv3_1)
    layer_flatten = layers.Flatten()(layer_conv3_2)

    dense_hidden1 = layers.Dense(32, activation='relu')(layer_flatten)
    dense_hidden2 = layers.Dense(64, activation='relu')(dense_hidden1)
    dense_hidden3 = layers.Dense(128, activation='relu')(dense_hidden2)

    dense_output = layers.Dense(10, activation='softmax')(dense_hidden3)

    model = Model(inputs=[input_layer], outputs=[dense_output])

    return model

# %%
def get_data():
    digit_dataset = load_digits()

    digit_data = digit_dataset.images
    digit_data = np.divide(digit_data, 255)  # Transform 0-255 to 0-1
    digit_data = np.expand_dims(digit_data, axis=-1)  # Add extra dimension to 2D image to make it 3D

    return digit_data, digit_dataset.target

# %%
X, y = get_data()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=RANDOM_SEED)

# %%
# Check data has been loaded property
plt.figure(figsize=(10, 10))
plt.title("Random train sample", pad=30)
plt.axis("off")

for i in range(9):
    random_num = random.randint(0, X_train.shape[0])
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(X_train[random_num], cmap='gray')
    plt.title(y_train[random_num])
    plt.axis("off")

# %%
model_base = create_model()
model_base.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='digit_model.keras',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True,
    verbose=True)

history_model_base = model_base.fit(x=X_train,
                                    y=y_train,
                                    epochs=40,
                                    validation_data=(X_test, y_test),
                                    callbacks=[model_checkpoint_callback],
                                    verbose=True)
# Out:
# Epoch 1/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.1130 - loss: 2.2764
# Epoch 1: val_accuracy improved from -inf to 0.21111, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.1139 - loss: 2.2741 - val_accuracy: 0.2111 - val_loss: 2.0865
# Epoch 2/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.2439 - loss: 1.9292
# Epoch 2: val_accuracy improved from 0.21111 to 0.46111, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.2459 - loss: 1.9220 - val_accuracy: 0.4611 - val_loss: 1.3298
# Epoch 3/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4535 - loss: 1.3325
# Epoch 3: val_accuracy improved from 0.46111 to 0.60926, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.4552 - loss: 1.3294 - val_accuracy: 0.6093 - val_loss: 1.1063
# Epoch 4/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5888 - loss: 1.0671
# Epoch 4: val_accuracy improved from 0.60926 to 0.71481, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.5900 - loss: 1.0626 - val_accuracy: 0.7148 - val_loss: 0.7321
# Epoch 5/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7331 - loss: 0.6683
# Epoch 5: val_accuracy improved from 0.71481 to 0.78519, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.7336 - loss: 0.6680 - val_accuracy: 0.7852 - val_loss: 0.5327
# Epoch 6/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8191 - loss: 0.5096
# Epoch 6: val_accuracy improved from 0.78519 to 0.79630, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.8196 - loss: 0.5090 - val_accuracy: 0.7963 - val_loss: 0.5480
# Epoch 7/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8408 - loss: 0.4489
# Epoch 7: val_accuracy improved from 0.79630 to 0.87037, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.8413 - loss: 0.4468 - val_accuracy: 0.8704 - val_loss: 0.4189
# Epoch 8/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8829 - loss: 0.3345
# Epoch 8: val_accuracy improved from 0.87037 to 0.92222, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.8831 - loss: 0.3347 - val_accuracy: 0.9222 - val_loss: 0.2949
# Epoch 9/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9441 - loss: 0.1965
# Epoch 9: val_accuracy improved from 0.92222 to 0.92593, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9443 - loss: 0.1963 - val_accuracy: 0.9259 - val_loss: 0.2808
# Epoch 10/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9629 - loss: 0.1288
# Epoch 10: val_accuracy improved from 0.92593 to 0.93148, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9626 - loss: 0.1293 - val_accuracy: 0.9315 - val_loss: 0.2198
# Epoch 11/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9728 - loss: 0.0864
# Epoch 11: val_accuracy improved from 0.93148 to 0.95000, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9725 - loss: 0.0870 - val_accuracy: 0.9500 - val_loss: 0.1600
# Epoch 12/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9605 - loss: 0.1303
# Epoch 12: val_accuracy did not improve from 0.95000
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9607 - loss: 0.1299 - val_accuracy: 0.9500 - val_loss: 0.1523
# Epoch 13/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9703 - loss: 0.0739
# Epoch 13: val_accuracy improved from 0.95000 to 0.97407, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9705 - loss: 0.0738 - val_accuracy: 0.9741 - val_loss: 0.0956
# Epoch 14/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9908 - loss: 0.0293
# Epoch 14: val_accuracy did not improve from 0.97407
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9904 - loss: 0.0310 - val_accuracy: 0.9556 - val_loss: 0.1762
# Epoch 15/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9507 - loss: 0.1600
# Epoch 15: val_accuracy did not improve from 0.97407
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9515 - loss: 0.1574 - val_accuracy: 0.9741 - val_loss: 0.1150
# Epoch 16/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9794 - loss: 0.0507
# Epoch 16: val_accuracy did not improve from 0.97407
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9793 - loss: 0.0516 - val_accuracy: 0.9630 - val_loss: 0.0931
# Epoch 17/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9801 - loss: 0.0393
# Epoch 17: val_accuracy did not improve from 0.97407
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9803 - loss: 0.0394 - val_accuracy: 0.9611 - val_loss: 0.1244
# Epoch 18/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9857 - loss: 0.0280
# Epoch 18: val_accuracy improved from 0.97407 to 0.98148, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9859 - loss: 0.0280 - val_accuracy: 0.9815 - val_loss: 0.0841
# Epoch 19/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9889 - loss: 0.0359
# Epoch 19: val_accuracy did not improve from 0.98148
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9887 - loss: 0.0370 - val_accuracy: 0.9796 - val_loss: 0.0771
# Epoch 20/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9924 - loss: 0.0239
# Epoch 20: val_accuracy improved from 0.98148 to 0.98889, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9921 - loss: 0.0243 - val_accuracy: 0.9889 - val_loss: 0.0334
# Epoch 21/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9950 - loss: 0.0284
# Epoch 21: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9949 - loss: 0.0289 - val_accuracy: 0.9741 - val_loss: 0.1010
# Epoch 22/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9904 - loss: 0.0222
# Epoch 22: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9905 - loss: 0.0229 - val_accuracy: 0.9759 - val_loss: 0.0918
# Epoch 23/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9891 - loss: 0.0349
# Epoch 23: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9893 - loss: 0.0341 - val_accuracy: 0.9741 - val_loss: 0.1137
# Epoch 24/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9887 - loss: 0.0412
# Epoch 24: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9888 - loss: 0.0411 - val_accuracy: 0.9778 - val_loss: 0.1061
# Epoch 25/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9950 - loss: 0.0302
# Epoch 25: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9951 - loss: 0.0299 - val_accuracy: 0.9722 - val_loss: 0.1005
# Epoch 26/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9969 - loss: 0.0135
# Epoch 26: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9966 - loss: 0.0144 - val_accuracy: 0.9759 - val_loss: 0.0783
# Epoch 27/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9919 - loss: 0.0281
# Epoch 27: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9918 - loss: 0.0282 - val_accuracy: 0.9741 - val_loss: 0.0967
# Epoch 28/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9891 - loss: 0.0212
# Epoch 28: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9892 - loss: 0.0211 - val_accuracy: 0.9815 - val_loss: 0.0922
# Epoch 29/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9953 - loss: 0.0214
# Epoch 29: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9951 - loss: 0.0224 - val_accuracy: 0.9741 - val_loss: 0.0926
# Epoch 30/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9893 - loss: 0.0395
# Epoch 30: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9886 - loss: 0.0420 - val_accuracy: 0.9574 - val_loss: 0.1733
# Epoch 31/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9876 - loss: 0.0453
# Epoch 31: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9876 - loss: 0.0454 - val_accuracy: 0.9796 - val_loss: 0.1302
# Epoch 32/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9850 - loss: 0.0555
# Epoch 32: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9852 - loss: 0.0551 - val_accuracy: 0.9852 - val_loss: 0.0545
# Epoch 33/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9970 - loss: 0.0111
# Epoch 33: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9970 - loss: 0.0112 - val_accuracy: 0.9833 - val_loss: 0.0605
# Epoch 34/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9949 - loss: 0.0196
# Epoch 34: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9948 - loss: 0.0202 - val_accuracy: 0.9667 - val_loss: 0.1107
# Epoch 35/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9875 - loss: 0.0353
# Epoch 35: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9878 - loss: 0.0347 - val_accuracy: 0.9759 - val_loss: 0.1172
# Epoch 36/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9929 - loss: 0.0230
# Epoch 36: val_accuracy did not improve from 0.98889
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9928 - loss: 0.0237 - val_accuracy: 0.9667 - val_loss: 0.1430
# Epoch 37/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9929 - loss: 0.0305
# Epoch 37: val_accuracy improved from 0.98889 to 0.99259, saving model to digit_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9930 - loss: 0.0302 - val_accuracy: 0.9926 - val_loss: 0.0170
# Epoch 38/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 7.0314e-04
# Epoch 38: val_accuracy did not improve from 0.99259
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 1.0000 - loss: 6.9428e-04 - val_accuracy: 0.9833 - val_loss: 0.0698
# Epoch 39/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 5.8612e-04
# Epoch 39: val_accuracy did not improve from 0.99259
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 1.0000 - loss: 5.7324e-04 - val_accuracy: 0.9907 - val_loss: 0.0213
# Epoch 40/40
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 1.9685e-05
# Epoch 40: val_accuracy did not improve from 0.99259
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 1.0000 - loss: 2.0194e-05 - val_accuracy: 0.9870 - val_loss: 0.0219

# %%
np.save('./history.npy', history_model_base.history)

# %%
# Método para la visualización de la exactitud obtenida durante el proceso de entrenamiento tanto en entrenamiento como en validación
def plot_losses(history):
    figure = plt.figure()
    axes = figure.add_subplot()
    axes.set_facecolor("#F0F7FF")
    axes.plot(history.history['loss'], label="Training", linestyle='dashed', color='#003B80')
    axes.plot(history.history['val_loss'], label="Validation", color='#003B80')
    axes.legend(loc="best")
    axes.set_ylabel('Loss')
    axes.set_xlabel('Epochs')
    axes.set_title('Loss during training')
    return figure


# Método para la visualización de la exactitud obtenida durante el proceso de entrenamiento tanto en entrenamiento como en validación
def plot_accuracy(history):
    figure = plt.figure()
    axes = figure.add_subplot()
    axes.set_facecolor("#F0F7FF")
    axes.plot(history.history['accuracy'], label="Training", linestyle='dashed', color='#003B80')
    axes.plot(history.history['val_accuracy'], label="Validation", color='#003B80')
    axes.legend(loc="best")
    axes.set_ylabel('Accuracy')
    axes.set_xlabel('Epochs')
    axes.set_title('Accuracy during training')
    return figure

# %%
_ = plot_losses(history_model_base)

# %%
_ = plot_accuracy(history_model_base)
